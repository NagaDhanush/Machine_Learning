# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas
df=pandas.read_csv('/content/drive/My Drive/dataset/nagabitcoin.csv')
df.count()
# Out:
# Date     90
# Open     90
# High     90
# Low      90
# Close    90
# dtype: int64

# %%
df.head(9)
# Out:
#          Date     Open    High      Low    Close
# 0  01/01/2017   991.50  1000.0   969.01   969.01
# 1  02/01/2017  1014.00  1400.0   971.51  1060.00
# 2  03/01/2017  1006.59  1069.5  1006.59  1069.49
# 3  04/01/2017  1070.00  1240.0  1070.00  1210.00
# 4  05/01/2017  1210.00  1212.0   955.08  1068.00
# 5  06/01/2017  1016.01  1080.0   931.00  1001.00
# 6  07/01/2017   942.00  1001.0   860.00   967.50
# 7  08/01/2017   967.50   990.0   901.34   902.01
# 8  09/01/2017   922.50   999.0   922.50   960.00

# %%
import numpy as np
a= np.array(df['Open'][:70])
b=np.array(df['Close'][:70])
print(a)
print(b)
c= a-b
# Out:
# [ 991.5  1014.   1006.59 1070.   1210.   1016.01  942.    967.5   922.5
#   940.5   974.    850.    800.06  869.    850.    846.    700.    939.
#   900.    918.5   934.97  938.9   924.01  927.51  918.    921.52  930.
#   949.9   942.02  938.    949.99  988.    998.9  1022.   1037.5  1033.
#  1042.98 1036.01 1082.   1070.11  997.   1021.   1039.   1035.   1007.
#  1040.   1028.   1050.   1089.99 1079.   1062.5  1080.19 1155.   1162.5
#  1184.51 1183.99 1171.99 1155.51 1230.99 1205.   1224.52 1259.   1290.
#  1301.49 1275.01 1293.   1237.01 1150.03 1206.   1167.95]
# [ 969.01 1060.   1069.49 1210.   1068.   1001.    967.5   902.01  960.
#   941.5   820.    899.99  822.01  867.    823.01  600.    940.    890.
#   948.    921.    938.99  939.    950.    938.5   921.52  939.    926.5
#   940.    938.    950.    995.    998.9  1010.   1017.   1059.   1042.98
#  1046.95 1082.   1069.5  1008.49  997.   1039.99 1035.   1011.   1054.
# ...

# %%
print(c)
# Out:
# [ 2.249e+01 -4.600e+01 -6.290e+01 -1.400e+02  1.420e+02  1.501e+01
#  -2.550e+01  6.549e+01 -3.750e+01 -1.000e+00  1.540e+02 -4.999e+01
#  -2.195e+01  2.000e+00  2.699e+01  2.460e+02 -2.400e+02  4.900e+01
#  -4.800e+01 -2.500e+00 -4.020e+00 -1.000e-01 -2.599e+01 -1.099e+01
#  -3.520e+00 -1.748e+01  3.500e+00  9.900e+00  4.020e+00 -1.200e+01
#  -4.501e+01 -1.090e+01 -1.110e+01  5.000e+00 -2.150e+01 -9.980e+00
#  -3.970e+00 -4.599e+01  1.250e+01  6.162e+01  0.000e+00 -1.899e+01
#   4.000e+00  2.400e+01 -4.700e+01  1.200e+01 -2.200e+01 -4.000e+01
#   1.099e+01  1.650e+01 -2.750e+01 -7.680e+01 -2.100e+01 -3.099e+01
#   5.200e-01  1.100e+01  1.698e+01 -7.549e+01  2.649e+01 -3.900e+01
#  -4.047e+01 -3.599e+01 -1.200e+01  2.848e+01 -1.799e+01  2.800e+01
#   8.697e+01 -6.965e+01  6.200e+01 -3.205e+01]

# %%
d=np.array(df['Date'][:70])
print(d)
# Out:
# ['01/01/2017' '02/01/2017' '03/01/2017' '04/01/2017' '05/01/2017'
#  '06/01/2017' '07/01/2017' '08/01/2017' '09/01/2017' '10/01/2017'
#  '11/01/2017' '12/01/2017' '13/01/2017' '14/01/2017' '15/01/2017'
#  '16/01/2017' '17/01/2017' '18/01/2017' '19/01/2017' '20/01/2017'
#  '21/01/2017' '22/01/2017' '23/01/2017' '24/01/2017' '25/01/2017'
#  '26/01/2017' '27/01/2017' '28/01/2017' '29/01/2017' '30/01/2017'
#  '31/01/2017' '01/02/2017' '02/02/2017' '03/02/2017' '04/02/2017'
#  '05/02/2017' '06/02/2017' '07/02/2017' '08/02/2017' '09/02/2017'
#  '10/02/2017' '11/02/2017' '12/02/2017' '13/02/2017' '14/02/2017'
#  '15/02/2017' '16/02/2017' '17/02/2017' '18/02/2017' '19/02/2017'
#  '20/02/2017' '21/02/2017' '22/02/2017' '23/02/2017' '24/02/2017'
#  '25/02/2017' '26/02/2017' '27/02/2017' '28/02/2017' '01/03/2017'
#  '02/03/2017' '03/03/2017' '04/03/2017' '05/03/2017' '06/03/2017'
#  '07/03/2017' '08/03/2017' '09/03/2017' '10/03/2017' '11/03/2017']

# %%
import matplotlib.pyplot as plt
#plt.plot(x,y, plot_property)
plt.rcParams['figure.figsize'] = (25,20)
plt.plot(d,c,'ro-') 
plt.xlabel('date')
plt.ylabel('Profit or loss')
plt.show()

# %%
dfw=pandas.read_csv('/content/drive/My Drive/dataset/dhanushwinequality.csv')
dfw.head()
dfw.count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
import numpy as np
r=np.array(dfw['quality'])
r.sort()
r_unique, r_count = np.unique(r, return_counts=True)
print(r_unique)
print(r_count)
# Out:
# [3 4 5 6 7 8]
# [ 10  53 681 638 199  18]

# %%
print(sum(r_count))
# Out:
# 1599

# %%
plt.bar(r_unique,r_count,0.2)
plt.show()
